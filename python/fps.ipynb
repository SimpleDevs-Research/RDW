# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
fps = pd.read_csv('./samples/With_FPS/PCVR-FPS-ConfThresh_0/FPS_Control.csv')
fps['trial_ms'] = fps['unix_ms'] - fps['unix_ms'].iloc[0]
fps['trial_sec'] = fps['trial_ms']/1000
fps.plot(x='trial_sec',y='current_fps')
# Out:
# <Axes: xlabel='trial_sec'>
